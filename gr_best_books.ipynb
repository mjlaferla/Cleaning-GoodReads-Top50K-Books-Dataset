# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data source from https://www.goodreads.com/list/show/1.Best_Books_Ever
best_books_df = pd.read_csv('C:/Users/mitchell.laferla/Documents/Data_Sources/book_data.csv')

# %%
cols = [
    'book_title', 'book_authors', 'book_desc',
    'genres', 'book_pages', 'book_rating', 
    'book_rating_count', 'book_review_count', 'book_format',
    'book_edition', 'book_isbn', 'image_url'
    ]

best_books_df = best_books_df[cols]

# %%
best_books_df.head(5)
# Out:
#                                   book_title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                            book_desc  \
# 0  Winning will make you famous. Losing means cer...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
#
# ...
